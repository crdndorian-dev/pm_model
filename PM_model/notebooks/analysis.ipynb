# %%
# %run ../scripts/create_slug_list.py

# %%
# %run ../scripts/fetch_pm_data.py
# Out:
# Loaded 10 slugs. Taking snapshot at 2026-01-16T21:34:32.783561+00:00
# Fetched 130 market rows.
# Saved to: ../data/polymarket_price_snapshots.csv
# Rows with missing yes/no price: 0

# %%
# %run ../scripts/fetch_yf_data.py
# Out:
# Processing 10 (ticker, expiry) groups
# ✅ Saved RN probabilities to ../data/options_risk_neutral_probabilities.csv

# %%
# %run ../scripts/deltaP_calculator.py
# Out:
# ✅ Saved delta P table to: ../data/delta_p_snapshots.csv
# Rows written this run: 130

# %%
# %run ../scripts/outcome_collector.py
# Out:
# ...
# ✅ [1/10] slug=nvda-above-on-january-16-2026 markets=13
# ✅ [2/10] slug=aapl-above-on-january-16-2026 markets=13
# ✅ [3/10] slug=googl-above-on-january-16-2026 markets=13
# ✅ [4/10] slug=msft-above-on-january-16-2026 markets=13
# ✅ [5/10] slug=meta-above-on-january-16-2026 markets=13
# ✅ [6/10] slug=amzn-above-on-january-16-2026 markets=13
# ✅ [7/10] slug=tsla-above-on-january-16-2026 markets=13
# ✅ [8/10] slug=pltr-above-on-january-16-2026 markets=13
# ✅ [9/10] slug=open-above-on-january-16-2026 markets=13
# ✅ [10/10] slug=nflx-above-on-january-16-2026 markets=13
#
# ✅ Wrote 130 rows to history.
# ✅ Latest file updated. Resolved markets found this run: 130
# 📄 HISTORY: ../data/market_outcomes_history.csv
# 📄 LATEST : ../data/market_outcomes_latest.csv

# %%
# %run ../scripts/clean_data.py
# Out:
# ✅ Wrote clean history: ../data/clean_data_history.csv (49 rows)
# ✅ Wrote clean latest : ../data/clean_data_latest.csv (49 rows)

# %%
# %run ../scripts/cluster_analysis.py
# Out:
# /Users/dorianc./Desktop/PM_model/scripts/cluster_analysis.py:249: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g[g["snapshot_time_utc"] == g["snapshot_time_utc"].max()])
# === Shrinkage fit ===
# Scope: same_weekday
# Best lambda: 0.500 (mean cluster pnl in-sample: 0.4298)
# Top 10 lambdas:
#  lambda  mean_cluster_pnl
#    0.50          0.429833
#    0.64          0.429833
#    0.74          0.429833
#    0.73          0.429833
#    0.72          0.429833
#    0.71          0.429833
#    0.70          0.429833
#    0.69          0.429833
#    0.68          0.429833
#    0.67          0.429833
#
# === Week/weekday cluster summary (one trade per ticker-week) ===
# ...

# %%
# %run ../scripts/lambda_analysis.py
# Out:
# ...
# SUMMARY
# ...
# N trades: 9
# Total PnL: 3.8685
# Avg PnL: 0.42983333333333335
# Median PnL: 0.471
# % profitable: 1.0
# Win rate: 1.0
# Mean predicted win prob: 0.781342711111111
# Sharpe-like (mean/std): 3.226436244192025
#
# ...
# CALIBRATION (predicted win prob buckets)
# ...
#      p_bucket  n  avg_pred  win_rate  avg_pnl
# (-0.001, 0.1]  0       NaN       NaN      NaN
#    (0.1, 0.2]  0       NaN       NaN      NaN
#   (0.2, 0.35]  0       NaN       NaN      NaN
#   (0.35, 0.5]  0       NaN       NaN      NaN
#   (0.5, 0.65]  0       NaN       NaN      NaN
#   (0.65, 0.8]  7  0.751048       1.0 0.488286
#    (0.8, 0.9]  1  0.832500       1.0 0.335000
#    (0.9, 1.0]  1  0.942250       1.0 0.115500
#
# ...
# EV → PnL (bucket + correlation)
# ...
# Correlation(best_ev_lambda, trade_pnl): 0.9866087205605814
#     ev_bucket  n   avg_ev  avg_pnl  win_rate
# (-1.001, 0.0]  0      NaN      NaN       NaN
#   (0.0, 0.02]  0      NaN      NaN       NaN
#  (0.02, 0.05]  0      NaN      NaN       NaN
# ...

# %%
# %matplotlib inline
# !python ../scripts/plot_cluster_metrics.py --ticker NVDA --week 01-16-2026 --Friday
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)

# %%
pip install pandas requests yfinance scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
