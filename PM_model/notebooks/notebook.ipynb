# %%
# !python /Users/dorianc./Desktop/PM_model/scripts/fetch_data.py --keep-invalid --out-dir "/Users/dorianc./Desktop/PM_model/data"
# Out:
# [Week] Today (local): 2026-01-18  |  Week: 2026-01-12 → 2026-01-18  |  Closes Friday: 2026-01-16
# [Tickers] Selected 10 tickers: NVDA, AAPL, GOOGL, MSFT, META, AMZN, TSLA, PLTR, OPEN, NFLX
# [Run] run_id: 20260118T121214Z
# [Run] run_dir: /Users/dorianc./Desktop/PM_model/data/runs/20260118T121214Z
# [Write] /Users/dorianc./Desktop/PM_model/data/runs/20260118T121214Z/polymarket_target_markets.csv
# [Write] /Users/dorianc./Desktop/PM_model/data/runs/20260118T121214Z/polymarket_price_snapshots.csv (rows=130)
# [yfinance] Processing 0 (ticker, expiry) groups
# [Write] /Users/dorianc./Desktop/PM_model/data/runs/20260118T121214Z/options_risk_neutral_probabilities.csv (rows=0)
# [Write] /Users/dorianc./Desktop/PM_model/data/polymarket_price_snapshots.csv  (rows=130)
# [yfinance] Processing 0 (ticker, expiry) groups
# [Write] /Users/dorianc./Desktop/PM_model/data/options_risk_neutral_probabilities.csv  (rows=0)
# [History] appended final rows
# ...

# %%
# !python /Users/dorianc./Desktop/PM_model/scripts/weekly_outcome_labeler.py \
  --snapshot-history "/Users/dorianc./Desktop/PM_model/data/history/final_dataset_history.csv" \
  --combined-out "/Users/dorianc./Desktop/PM_model/data/final_dataset_with_outcomes_history.csv" \
  --tz "Europe/Paris" \
  --only-expired
# Out:
# [Need] outcomes pairs: 130
# ✅ [1/10] slug=aapl-above-on-january-16-2026 fetched
# ✅ [2/10] slug=amzn-above-on-january-16-2026 fetched
# ✅ [3/10] slug=googl-above-on-january-16-2026 fetched
# ✅ [4/10] slug=meta-above-on-january-16-2026 fetched
# ✅ [5/10] slug=msft-above-on-january-16-2026 fetched
# ✅ [6/10] slug=nflx-above-on-january-16-2026 fetched
# ✅ [7/10] slug=nvda-above-on-january-16-2026 fetched
# ✅ [8/10] slug=open-above-on-january-16-2026 fetched
# ✅ [9/10] slug=pltr-above-on-january-16-2026 fetched
# ✅ [10/10] slug=tsla-above-on-january-16-2026 fetched
# [Outcomes] fetched rows=130  resolved=130
# /Users/dorianc./Desktop/PM_model/scripts/weekly_outcome_labeler.py:554: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
# ...
